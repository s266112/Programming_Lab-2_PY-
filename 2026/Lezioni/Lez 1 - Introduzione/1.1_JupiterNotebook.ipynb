# %% [markdown]
# # Jupyter Notebooks
#
# È una interfaccia che permette di scrivere, eseguire e condividere codice interattivo

# %% [markdown]
# #### Aggiunta e spostamento delle celle
#
# Aggiungi nuove celle utilizzando i pulsanti **+ Code** e **+ Markdown**, che appaiono quando passi il mouse tra le celle.
#
# Puoi spostare una cella selezionandola col mouse e muovendoti su e giù col mouse o le option + frecce

# %% [markdown]
# ### Celle Markdown Cell vs. Celle Python

# %% [markdown]
# Questo è un testo Markdown

# %%
"Questa è una cella python"
# Out:
# 'Questa è una cella python'

# %% [markdown]
# ### Come eseguire una cella
#
# - Clicca il pulsante di esecuzione.
#
# - Con la cella selezionata, premi **Cmd/Ctrl+Enter**.
#
# - Dentro alla cella premi **Shift+Enter**

# %%
print('ciao')
# Out:
# ciao

# %% [markdown]
# ### Note per Jupyter

# %% [markdown]
# Se hai più righe, solo l'ultima riga verrà mostrata.

# %%
2 + 2
"Ciaooo"
# Out:
# 'Ciaooo'

# %%
2 + 2, "Ciaooo"
# Out:
# (4, 'Ciaooo')

# %% [markdown]
# Se si stampa esegue la funzione stampa e quindi stampa tutto quello che è messo dentro i vari print.

# %%
print(2 + 2)
print(3 * 3)
print("Ciaooo")
# Out:
# 4
# 9
# Ciaooo

# %%
# Questo è un commento come sempre

print("Ciaooo")
print(2 + 2) # Anche questo
print(3 * 3)
# Out:
# Ciaooo
# 4
# 9

# %% [markdown]
# ## Nozioni di base su Markdown
#
# Markdown è un linguaggio di markup leggero che utilizza caratteri come `#` per i titoli e `*` per l'enfasi, permettendo di formattare il testo in modo semplice e intuitivo.

# %% [markdown]
# | Element        | Markdown Syntax                        |
# |----------------|----------------------------------------|
# | Heading        | `# H1`<br>`## H2`<br>`### H3`          |
# | Bold           | `**bold text**`                        |
# | Italic         | `*italicized text*`                    |
# | Blockquote     | `> blockquote`                         |
# | Ordered List   | `1. First item`<br>`2. Second item`<br>`3. Third item` |
# | Unordered List | `- First item`<br>`- Second item`<br>`- Third item`   |
# | Code           | `` `code` ``                           |
# | Horizontal Rule| `---`                                  |
# | Link           | `[title](https://www.example.com)`     |
# | Image          | `![alt text](image.jpg)`               |
#
# [Qui più info su Markdown](https://www.markdownguide.org/basic-syntax/)

# %% [markdown]
# ## Uso avanzato di Jupyter Notebook
#
# Iniziare una riga con uno dei seguenti simboli ha proprietà speciali.
#
# | Simbolo | Nome            | Esempio               | Spiegazione dell'uso                                                              |
# |---------|----------------|-----------------------|-----------------------------------------------------------------------------------|
# | `!`     | Comando Shell   | `!ls`                 | Esegue da terminale comandi della shell direttamente dalla cella del notebook, ad esempio elencare i file. |
# | `%`     | Magic Line      | `%cd sample_data`     | Esegue da IPython un comando magic su una singola riga, come cambiare directory.             |
# | `%%`    | Magic Cell      | `%%writefile test.txt` | Applica il comando magic all'intera cella, ad esempio scrivendo il contenuto della cella in un file. |

# %%
# !ls
# Out:
# 1.1_JupitierNotebook.ipynb 2.1_NumPy2.ipynb
# 1.2_Python_+.ipynb         2.2_Esercizi_lez_2.ipynb
# 1.3_NumPy.ipynb            Extra
# 1.4_Esercizi_lez_1.ipynb   esempio.ipynb
# 100_Numpy_exercises.ipynb  numpy_e_matplolib.ipynb

# %%
# %timeit [n*n for n in range(200)]
# Out:
# 2.83 μs ± 72 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit
lista = []
for n in range(200):
    lista.append(n*n)
# Out:
# 3.42 μs ± 13.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# Potete vedere le variabili salvate facilmente nella Jupiter cella

# %%
id_lavoro = 101
nome_azienda = 'DataWiz Inc.'
titolo_lavoro = 'Data Analyst'
stipendio_lavoro = 125000
lavoro_da_casa = True
