# %% [markdown]
# ## 1. La legge dei grandi numeri
#
# La legge dei grandi numeri è un teorema fondamentale della teoria della probabilità che indica che se ripetiamo molte volte (tendendo all'infinito) lo stesso esperimento, la frequenza di un certo evento tende ad essere costante.
#
# Vale a dire, **la legge dei grandi numeri indica che se lo stesso test viene eseguito ripetutamente (ad esempio, lancio di una moneta), la frequenza con cui si ripeterà un determinato evento (testa/croce) si avvicinerà a una costante. Questa a sua volta sarà la probabilità che questo evento si verifichi.**
#
# Fonte: https://it.economy-pedia.com/11038376-law-of-the-big-numbers
#
# 1. Scrivere una funzione che simula il lancio di una moneta per N volte e restituisce la frequenza % di volte che è uscita testa.
# 2. Calcolare la frequenza % con la grandezze del campione (numero di lanci) che varia 100 volte da 10 a 20000. Ottengo quindi 100 valori.
# 3. Fare il plot del Numero medio di teste (y) rispetto alla grandezza del campione (x)

# %% [markdown]
# ***Punto 1: Funzione per simulare il lancio della moneta***

# %%
import random
import matplotlib.pyplot as plt

# Funzione per simulare il lancio della moneta
def lancia_moneta(N):
    esiti = [random.choice(['testa', 'croce']) for _ in range(N)]
    testa_count = esiti.count ('testa')
    return (testa_count / N) * 100              # Restituisce la % di teste

# Provo con un esempio
risultato = lancia_moneta(1000)
print(f"Percentuale di teste su 1000 lanci: {risultato}%")
# Out:
# Percentuale di teste su 1000 lanci: 49.8%

# %% [markdown]
# ***Punto 2: Calcolare la frequenza % di testa per diversi valori di campione***

# %%
import numpy as np

# Creo 100 valori equidistanti tra 10 e 20.000
num_lanci = np.linspace(10, 20000, 100, dtype = int)        # 100 valori equidistanti tra 10 e 20.000

# Calcolo la frequenza di testa per ciascun valore di N
frequenze_testa = [lancia_moneta(N) for N in num_lanci]

# Stampo i risultati 
for i, frequenza in enumerate(frequenze_testa):
    print(f"N = {num_lanci[i]} lanci -> Frequenza di teste: {frequenza:.2f}%")

## INFO: np.linspace(start, stop, num): Genera 'num' valori equidistanti tra 'start' e 'stop'.
#                                       In questo caso, genera 100 valori tra 10 e 20.000.
# Out:
# N = 10 lanci -> Frequenza di teste: 40.00%
# N = 211 lanci -> Frequenza di teste: 51.66%
# N = 413 lanci -> Frequenza di teste: 48.18%
# N = 615 lanci -> Frequenza di teste: 50.89%
# N = 817 lanci -> Frequenza di teste: 48.96%
# N = 1019 lanci -> Frequenza di teste: 48.18%
# N = 1221 lanci -> Frequenza di teste: 50.45%
# N = 1423 lanci -> Frequenza di teste: 50.04%
# N = 1625 lanci -> Frequenza di teste: 52.74%
# N = 1827 lanci -> Frequenza di teste: 51.51%
# N = 2029 lanci -> Frequenza di teste: 49.83%
# N = 2231 lanci -> Frequenza di teste: 49.98%
# N = 2433 lanci -> Frequenza di teste: 50.02%
# N = 2634 lanci -> Frequenza di teste: 50.84%
# N = 2836 lanci -> Frequenza di teste: 49.75%
# N = 3038 lanci -> Frequenza di teste: 51.25%
# N = 14144 lanci -> Frequenza di teste: 50.24%
# N = 14346 lanci -> Frequenza di teste: 50.06%
# N = 14548 lanci -> Frequenza di teste: 49.70%
# N = 14750 lanci -> Frequenza di teste: 49.86%
# N = 14952 lanci -> Frequenza di teste: 50.35%
# N = 15153 lanci -> Frequenza di teste: 50.04%
# N = 15355 lanci -> Frequenza di teste: 49.83%
# N = 15557 lanci -> Frequenza di teste: 49.69%
# N = 15759 lanci -> Frequenza di teste: 49.97%
# N = 15961 lanci -> Frequenza di teste: 50.35%
# N = 16163 lanci -> Frequenza di teste: 50.45%
# N = 16365 lanci -> Frequenza di teste: 49.25%
# N = 16567 lanci -> Frequenza di teste: 50.43%
# N = 16769 lanci -> Frequenza di teste: 49.85%
# N = 16971 lanci -> Frequenza di teste: 49.87%
# N = 17173 lanci -> Frequenza di teste: 49.50%
# N = 17375 lanci -> Frequenza di teste: 50.30%
# N = 17576 lanci -> Frequenza di teste: 50.07%
# N = 17778 lanci -> Frequenza di teste: 49.79%
# N = 17980 lanci -> Frequenza di teste: 50.23%
# N = 18182 lanci -> Frequenza di teste: 49.49%
# N = 18384 lanci -> Frequenza di teste: 49.48%
# N = 18586 lanci -> Frequenza di teste: 49.56%
# N = 18788 lanci -> Frequenza di teste: 50.25%
# N = 18990 lanci -> Frequenza di teste: 49.95%
# N = 19192 lanci -> Frequenza di teste: 49.92%
# N = 19394 lanci -> Frequenza di teste: 50.16%
# N = 19596 lanci -> Frequenza di teste: 49.67%
# N = 19798 lanci -> Frequenza di teste: 50.75%
# N = 20000 lanci -> Frequenza di teste: 49.81%

# %% [markdown]
# ***Punto 3: Fare il plot del numero medio medio teste (y), rispetto alla grandezza del campione (x)***

# %%
# Creo il grafico
plt.figure(figsize=(10, 6))

# Traccio il numero medio di teste (y) rispetto alla randezza del campione (x)
plt.plot(num_lanci, frequenze_testa, color = 'blue', marker = 'o')

# Aggiungo il titolo e le etichette per gli assi
plt.title('Numero Medio di Teste vs Grandezza del Campione', fontsize=14)
plt.xlabel('Grandezza del Campione (N)', fontsize=12)
plt.ylabel('Numero Medio di Teste (%)', fontsize=12)

# Mostro la griglia e il grafico
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Analisi del Dataset Titanic
# 1. Quante righe e colonne ha il dataset?
# 2. Controlla quanti valori mancanti ci sono per colonna
# 3. Riempi i valori mancanti nella colonna 'Embarked' con il valore più frequente
# 4. Rimuovi le righe dove il valore di 'Age' è mancante
# 5. Controlla se ci sono righe duplicate
# 6. Calcola l'età media dei passeggeri per ogni classe (`Pclass`), se ci sono valori mancanti di età riempili con il valore medio
# 7. Visualizza la distribuzione dell'età per classe
# 8. Visualizza la distribuzione dell'età per classe dividendo e mostrando insieme i dati di uomini e donne

# %%
# Caricamento del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
titanic = pd.read_csv(url)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ***Punto 1:  Qunte righe e colonne ha il dataset?***

# %%
# Informazioni generali sul dataset
titanic.info()

# Ottengo il numero di righe e colonne
righe, colonne = titanic.shape

# Stampo la risposta
print(f"Il dataset contiene {righe} righe e {colonne} colonne.")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB
# Il dataset contiene 891 righe e 12 colonne.

# %% [markdown]
#  ***Punto 2: Quanti valori mancanti ci sono per colonna?***

# %%
# Numero di NaN per ciascuna colonna
valori_mancanti = titanic.isnull(). sum()

# Stampo solo le colonne che hanno almeno 1 NaN
print(valori_mancanti[valori_mancanti > 0])
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ***Punto 3: Riempi i valori mancanti nella colonna 'Embarked' con il valore più frequente***

# %%
# Trovo il valore più frequente nella colonna 'Embarked'
più_frequente = titanic['Embarked'].mode()[0]
print(f"Valore più frequente nella colonna 'Embarked': {più_frequente}")

# Riempio i valori mancanti con quel valore
titanic['Embarked'] = titanic['Embarked'].fillna(più_frequente)

# Controllo che non ci sono piu NaN
print("Valori mancanti in 'Embarked' dopo il riempimento:", titanic['Embarked'].isnull().sum())
# Out:
# Valore più frequente nella colonna 'Embarked': S
# Valori mancanti in 'Embarked' dopo il riempimento: 0

# %% [markdown]
# ***Punto 4: Rimuovi le righe dove il valore di 'Age' è mancante***

# %%
# Controllo quante righe ci sono prima del filtraggio
print("Righe prima della rimozione:", len(titanic))

# Rimuovo le righe con valori NaN in 'Age'
df = titanic[titanic['Age'].notnull()]

# Controllo le righe rimaste dopo il filtraggio
print("Righe dopo la rimozione:", len(df))
# Out:
# Righe prima della rimozione: 891
# Righe dopo la rimozione: 714

# %% [markdown]
# ***Punto 5: Controlla se ci sono righe duplicate***

# %%
# Controllo quante righe duplicate ci sono
duplicati = titanic.duplicated(). sum()
print(f"Numero di righe duplicate nel dataset: {duplicati}")

# Controllo quali sono le righe duplicate
titanic[titanic.duplicated()]
# Out:
# Numero di righe duplicate nel dataset: 0
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ***Punto 6: Calcola l’età media dei passeggeri per ogni classe (Pclass)***

# %%
# Età media dei passeggeri per ciascuna classe (Pclass)
eta_media_classe = titanic.groupby('Pclass')['Age'].mean()

# Stampo il risultato
for classe, media in eta_media_classe.items():
    print(f"Classe {classe}: età media = {media:.2f} anni")
# Out:
# Classe 1: età media = 38.23 anni
# Classe 2: età media = 29.88 anni
# Classe 3: età media = 25.14 anni

# %% [markdown]
# ***Punto 7: Visualizza la distribuzione dell’età per classe***

# %%
# Creo un FacetGrid con un grafico per ogni classe
g = sns.FacetGrid(df, col="Pclass", height=4, aspect=1.2)

# Aggiungo l'istogramma dell'età a ciascun pannello
g.map(sns.histplot, "Age", bins=30, color="skyblue")

# Aggiunge titoli e assi
g.set_titles("Classe {col_name}")
g.set_axis_labels("Età", "Conteggio")

# Titolo principale del grafico
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Distribuzione dell'età per classe", fontsize=16)

# Mostro il grafico
plt.show()

# %% [markdown]
# ***Punto 8: Visualizza la distribuzione dell’età per classe dividendo uomini e donne***

# %%
# Distribuzione dell'età per classe, separata per sesso
g = sns.FacetGrid(df, col="Sex", height=4, aspect=1.2)
g.map_dataframe(
    sns.histplot,
    x="Age",
    hue="Pclass",
    multiple="stack",
    bins=30,
    palette="Set2"
)

# Titoli e assi
g.set_titles("Sesso: {col_name}")
g.set_axis_labels("Età", "Conteggio")
g.add_legend()

# Titolo generale
g.fig.suptitle("Distribuzione dell'età per classe e sesso", fontsize=16)
plt.subplots_adjust(top=0.8)

# Mostro il grafico
plt.show()

# %% [markdown]
# ## 3. Analisi del Dataset Iris
#
# 1. Esplora la distribuzione delle specie (conta quanti campioni ci sono per specie)
# 2. Calcola la lunghezza e la larghezza media dei petali per specie
# 3. Visualizza le dimensioni dei petali per specie (scatterplot)
# 4. Crea una nuova colonna per l'area del petalo e analizzala
# 5. Grafico della distribuzione dell'area del petalo per specie (boxplot)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
iris= pd.read_csv(url)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ***Punto 1: Esplora la distribuzione delle specie (conta quanti campioni ci sono per specie)***

# %%
#  Conto i campioni di ciascuna specie
conteggio_specie = iris['species'].value_counts()
print(conteggio_specie)
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ***Punto 2: Calcola la lunghezza e la larghezza media dei petali per specie***

# %%
# Calcolo la lunghezza e la larghezza media dei petali di ogni specie
media_petali = iris.groupby('species')[['petal_length', 'petal_width']].mean()
print(media_petali)
# Out:
#             petal_length  petal_width
# species
# setosa             1.462        0.246
# versicolor         4.260        1.326
# virginica          5.552        2.026

# %% [markdown]
# ***Punto 3: Visualizza le dimensioni dei petali per specie (scatterplot)***

# %%
# Scatterplot delle dimensioni dei petali per specie
sns.scatterplot(
    data=iris, 
    x='petal_length', 
    y='petal_width', 
    hue='species', 
    palette='Set1')

# Aggiungo titolo e assi
plt.title('Lunghezza petali vs Larghezza petali per Specie')
plt.xlabel('Lunghezza petali')
plt.ylabel('Larghezza petali')

# Mostro il grafico
plt.show()

# %% [markdown]
# ***Punto 4: Crea una nuova colonna per l’area del petalo e analizzala***

# %%
# Creo una nuova colonna "area_petalo" nel dataframe Iris
iris['area_petalo'] = iris['petal_length'] * iris['petal_width']

# Visualizzo le prime righe per controllare
iris[['petal_length', 'petal_width', 'area_petalo']].head()

# Statistica per specie (Aggiuntivo)
iris.groupby('species')['area_petalo'].mean().reset_index(name='media_area_petalo')
# Out:
#       species  media_area_petalo
# 0      setosa             0.3656
# 1  versicolor             5.7204
# 2   virginica            11.2962

# %% [markdown]
# ***Punto 5:  Grafico della distribuzione dell’area del petalo per specie***

# %%
# Boxplot dell'area del petalo per ciascuna specie
sns.boxplot(
    data=iris, 
    x='species', 
    y='area_petalo', 
    hue='species', 
    palette='Set2', 
    legend=False)

# Titolo e assi
plt.title("Distribuzione dell'area del petalo per specie")
plt.xlabel("Specie")
plt.ylabel("Area del Petalo")

# Mostro il grafico
plt.show()
